# %% [markdown]
# # Process CNA data

# %%
import os
import numpy as np
import pandas as pd

data_dir = "../data"
raw_folder_name = "raw"
processed_folder_name = "processed"
hgnc_symbol_entrezgene_id_mapping_file_name = "hgnc_to_entrezgene_id_mapping.tsv"

cancer_type_cna_file_name_mapping = {
    "BLCA": "TCGA.BLCA.sampleMap_Gistic2_CopyNumber_Gistic2_all_data_by_genes",
    "LUSC": "TCGA.LUSC.sampleMap_Gistic2_CopyNumber_Gistic2_all_data_by_genes",
    "OV": "TCGA.OV.sampleMap_Gistic2_CopyNumber_Gistic2_all_data_by_genes",
}

hgnc_symbol_entrezgene_id_mapping = dict(pd.read_csv(os.path.join(data_dir, processed_folder_name, hgnc_symbol_entrezgene_id_mapping_file_name), sep="\t").values)


def select_the_row_with_max_expression_per_gene(x):
    x_sum = x.values.sum(axis=1).ravel()
    x_argmax = np.argmax(x_sum)
    return x.iloc[x_argmax, :]


def get_cna_df(cancer_type: str) -> pd.DataFrame:
    cna_file_name = cancer_type_cna_file_name_mapping[cancer_type]
    cna_df = pd.read_csv(os.path.join(data_dir, raw_folder_name, cna_file_name), sep="\t")

    for index, row in cna_df.iterrows():
        gene_symbol_splitted = row["Gene Symbol"].split("|")
        if len(gene_symbol_splitted) == 1:
            cna_df.at[index, "entrezgene_id"] = hgnc_symbol_entrezgene_id_mapping.get(gene_symbol_splitted[0], np.NaN)
            cna_df.at[index, "ensembl_id"] = np.NaN
        elif len(gene_symbol_splitted) == 2:
            cna_df.at[index, "entrezgene_id"] = hgnc_symbol_entrezgene_id_mapping.get(gene_symbol_splitted[0], np.NaN)
            cna_df.at[index, "ensembl_id"] = gene_symbol_splitted[1]
        else:
            raise Exception("gene_symbol_splitted has more than 1 '|'s")
    
    cna_df = cna_df.drop(columns=["Gene Symbol", "ensembl_id"])
    cna_df = cna_df[~pd.isnull(cna_df["entrezgene_id"])]
    cna_df = cna_df.reset_index(drop=True)
    cna_df = cna_df.groupby("entrezgene_id").apply(lambda x: select_the_row_with_max_expression_per_gene(x)).reset_index(drop=True)
    cna_df = cna_df.T
    cna_df.columns = cna_df.loc["entrezgene_id", :]
    cna_df = cna_df.drop("entrezgene_id", axis=0)
    cna_df.columns = [int(column) for column in cna_df.columns]
    return cna_df

blca_cna_df = get_cna_df(cancer_type="BLCA")
lusc_cna_df = get_cna_df(cancer_type="LUSC")
ov_cna_df = get_cna_df(cancer_type="OV")

# %% [markdown]
# # Process RNA data

# %%
rna_data_file_name = "EBPlusPlusAdjustPANCAN_IlluminaHiSeq_RNASeqV2.geneExp.tsv"

rna_df = pd.read_csv(os.path.join(data_dir, raw_folder_name, rna_data_file_name), sep="\t")
rna_df["gene_id"] = rna_df["gene_id"].apply(lambda x: int(x.split("|")[1]))

tumor_sample_ids = ["0" + str(i) for i in range(1, 10)]

column_dict = {}
for column in rna_df.columns:
    if column == "gene_id":
        continue
    if column.split("-")[3] not in tumor_sample_ids:
        continue
    column_first_15 = column[:15]
    if column_first_15 in column_dict.keys():
        if column < column_dict[column_first_15]:
            column_dict[column_first_15] = column
        else:
            continue
    else:
        column_dict[column_first_15] = column

rna_df = rna_df[["gene_id"] + list(column_dict.values())]
rna_df.columns = [column[:15] for column in rna_df.columns]

rna_df = rna_df.T
rna_df.columns = rna_df.loc["gene_id", :]
rna_df = rna_df.drop("gene_id", axis=0)
rna_df.columns = [int(column) for column in rna_df.columns]

# %%
rna_df

# %% [markdown]
# # Process RPPA data

# %%
data_dir = "../data"
raw_folder_name = "raw"
rppa_data_file_name = "TCGA-RPPA-pancan-clean.txt"

rppa_df = pd.read_csv(os.path.join(data_dir, raw_folder_name, rppa_data_file_name), sep="\t")
rppa_df = rppa_df.drop(columns=["TumorType"])
rppa_df = rppa_df.T
rppa_df.columns = rppa_df.loc["SampleID", :].tolist()
rppa_df = rppa_df.drop("SampleID", axis=0)

column_dict = {}
for column in rppa_df.columns:
    if column.split("-")[3] not in tumor_sample_ids:
        continue
    column_first_15 = column[:15]
    if column_first_15 in column_dict.keys():
        if column < column_dict[column_first_15]:
            column_dict[column_first_15] = column
        else:
            continue
    else:
        column_dict[column_first_15] = column

rppa_df = rppa_df[list(column_dict.values())]

set([column.split("-")[-1] for column in rppa_df.columns])

# %%
set([sample_id.split("-")[-1] for sample_id in rppa_df["SampleID"]])
# Out:
# {'20', '23'}

# %%
(ov_cna_df.describe().loc["count", :] != 24776).sum()
# Out:
# 1

# %%
blca_cna_df = blca_cna_df[pd.isnull(blca_cna_df["entrezgene_id"])]
lusc_cna_df = lusc_cna_df[pd.isnull(lusc_cna_df["entrezgene_id"])]
ov_cna_df = ov_cna_df[pd.isnull(ov_cna_df["entrezgene_id"])]

# %%
blca_nan_genes = [column.split("|")[0] for column in blca_cna_df["Gene Symbol"].tolist()]
lusc_nan_genes = [column.split("|")[0] for column in lusc_cna_df["Gene Symbol"].tolist()]
ov_nan_genes = [column.split("|")[0] for column in ov_cna_df["Gene Symbol"].tolist()]

# %%
rna_df[rna_df.gene_id.isin(blca_nan_genes + lusc_nan_genes + ov_nan_genes)]
# Out:
#         gene_id  TCGA-OR-A5J1-01A-11R-A29S-07  TCGA-OR-A5J2-01A-11R-A29S-07  \
# 495       AKAP2                       25.9126                      555.1630
# 4243     CRIPAK                     1000.0000                      111.9310
# 6526   FLJ45079                        0.0000                        0.0000
# 12284      OCLM                        2.4015                        1.6105
# 12897     PALM2                       40.3458                       60.6361
# 13986  PRAMEF16                        0.0000                        0.0000
# 13992   PRAMEF3                        0.0000                        0.0000
# 17132     SPHAR                      187.5990                      103.2180
#
#        TCGA-OR-A5J3-01A-11R-A29S-07  TCGA-OR-A5J5-01A-11R-A29S-07  \
# 495                         89.4386                       23.1758
# 4243                       134.4990                      920.2170
# 6526                         0.0000                        0.0000
# 12284                        1.7775                        0.7746
# 12897                       34.3653                       44.9264
# 13986                        0.0000                        0.0000
# 13992                        0.0000                        0.0000
# 17132                      174.8250                      160.2250
#
#        TCGA-OR-A5J6-01A-31R-A29S-07  TCGA-OR-A5J7-01A-11R-A29S-07  \
# 495                        309.8690                      118.3190
# 4243                       161.5100                      202.5670
# 6526                         0.0000                        0.0000
# 12284                        0.0000                        3.2090
# 12897                       43.5908                        7.2202
# 13986                        0.0000                        0.0000
# 13992                        0.0000                        0.0000
# 17132                      242.2760                      209.5870
#
#        TCGA-OR-A5J8-01A-11R-A29S-07  TCGA-OR-A5J9-01A-11R-A29S-07  \
# 495                        321.7410                      187.4380
# 4243                       179.8590                      207.7280
# 6526                         1.6577                        0.0000
# 12284                        0.4144                        1.0199
# 12897                      149.6060                       36.3779
# 13986                        0.0000                        0.0000
# 13992                        0.0000                        0.0000
# 17132                       85.1057                      152.8990
#
#        TCGA-OR-A5JA-01A-11R-A29S-07  ...  TCGA-CG-4449-01A-01R-1157-13  \
# 495                        112.5580  ...                   1115.512151
# 4243                       401.6910  ...                    119.426172
# 6526                         0.0000  ...                      2.970308
# 12284                        0.0000  ...                      5.990349
# 12897                       54.4397  ...                     27.214875
# 13986                        0.0000  ...                           NaN
# 13992                        0.0000  ...                           NaN
# 17132                      142.5320  ...                     87.281454
#
#        TCGA-CG-4462-01A-01R-1157-13  TCGA-CG-4465-01A-01R-1157-13  \
# 495                     1472.113832                    441.238305
# 4243                     178.450011                    183.994794
# 6526                       0.663336                     -0.078105
# 12284                      4.757428                      2.636631
# 12897                     48.545469                     30.326484
# 13986                           NaN                           NaN
# 13992                           NaN                           NaN
# 17132                    116.091629                    100.504175
#
#        TCGA-CG-4466-01A-01R-1157-13  TCGA-CG-4469-01A-01R-1157-13  \
# 495                      179.135973                    850.465906
# 4243                     183.934078                    264.247540
# 6526                       8.367408                      1.410988
# 12284                     31.630210                     13.390735
# 12897                     38.163535                     16.352979
# 13986                           NaN                           NaN
# 13992                           NaN                           NaN
# 17132                    205.147945                    146.295648
#
#        TCGA-CG-4472-01A-01R-1157-13  TCGA-CG-4474-01A-02R-1157-13  \
# 495                      988.185730                    588.680385
# 4243                     170.322916                    298.361856
# 6526                      -0.078105                      2.685201
# 12284                      5.261172                      8.437542
# 12897                     27.482717                     84.796572
# 13986                           NaN                           NaN
# 13992                           NaN                           NaN
# 17132                    304.084884                    127.005765
#
#        TCGA-CG-4475-01A-01R-1157-13  TCGA-CG-4476-01A-01R-1157-13  \
# 495                      998.222727                    941.993199
# 4243                     635.248453                    238.273356
# 6526                      -0.078105                      2.310279
# 12284                      4.564389                      6.664620
# 12897                     60.752240                     17.386517
# 13986                           NaN                           NaN
# 13992                           NaN                           NaN
# 17132                    110.213938                    139.509572
#
#        TCGA-CG-4477-01A-01R-1157-13
# 495                     1036.272131
# 4243                     234.991948
# 6526                       5.190240
# 12284                      8.942182
# 12897                     42.649851
# 13986                           NaN
# 13992                           NaN
# 17132                    148.587225
#
# [8 rows x 11070 columns]

# %%
blca_nan_genes
# Out:
# ['MIR4417',
#  'snoU13',
#  'RN7SL729P',
#  'MIR1273D',
#  'RN7SL721P',
#  'snoU13',
#  'snoU13',
#  'PRAMEF16',
#  'PRAMEF3',
#  'snoU13',
#  'C1orf134',
#  'snoU13',
#  'RN7SL85P',
#  'snoU13',
#  'RN7SL421P',
#  'RN7SL768P',
#  'MIR4419A',
#  'RN7SL532P',
#  'RN7SL24P',
#  'snoU13',
#  'RN7SL857P',
#  'snoU13',
#  'snoU13',
#  'RN7SL490P',
#  'snoU13',
#  'RN7SL501P',
#  'snoU13',
#  'SCARNA24',
#  'FKSG48',
#  'RN7SL136P',
#  'RN7SL281P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'MIR1273F',
#  'MIR5095',
#  'MIR1273G',
#  'snoU13',
#  'SNORA2',
#  'snoU13',
#  'RN7SL235P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'SNORD59',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL374P',
#  'OCLM',
#  'snoU109',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL512P',
#  'snoU13',
#  'snoU13',
#  'RN7SL276P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'SPHAR',
#  'RN7SL467P',
#  'snoU13',
#  'snoU13',
#  'RNA5SP81',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'SNORA2',
#  'snoU13',
#  'SNORA36',
#  'snoZ247',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'Vault',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'MGC10955',
#  'snoU13',
#  'snoU109',
#  'snoU13',
#  'RN7SL830P',
#  'snoU13',
#  'snoU13',
#  'FLJ14082',
#  'snoU13',
#  'RN7SL611P',
#  'snoU13',
#  'RN7SL360P',
#  'RN7SL548P',
#  'FLJ20373',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL206P',
#  'snoU13',
#  'RN7SL701P',
#  'snoU13',
#  'snR65',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoZ5',
#  'RMRPP3',
#  'snoU13',
#  'snoU13',
#  'RN7SL95P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'SNORD59',
#  'snoU13',
#  'snoU13',
#  'Vault',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'MGC4771',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'MIR4792',
#  'RN7SL859P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'MIR566',
#  'snoU13',
#  'RN7SL821P',
#  'SNORD38',
#  'snoU13',
#  'NPCDR1',
#  'snoU13',
#  'snoU13',
#  'snoZ40',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'SNORA5',
#  'snoU13',
#  'MIR1280',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'MIR720',
#  'PP13439',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL637P',
#  'snoU13',
#  'RN7SL486P',
#  'snoU13',
#  'RN7SL773P',
#  'snoU13',
#  'RN7SL358P',
#  'CRIPAK',
#  'snoU13',
#  'RN7SL315P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SKP215',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'SNORD50',
#  'snoU13',
#  'MIR5096',
#  'snoR442',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'SNORD73',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL572P',
#  'snoU13',
#  'snoU13',
#  'MIR4459',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL103P',
#  'snoU13',
#  'RN7SL476P',
#  'RN7SL9P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoZ6',
#  'snoU13',
#  'MIR4461',
#  'snoU13',
#  'RN7SL682P',
#  'snoU13',
#  'RN7SL867P',
#  'SNORD45',
#  'snoU13',
#  'snoU13',
#  'RN7SL439P',
#  'RN7SL295P',
#  'snoU13',
#  'snoU13',
#  'RN7SL562P',
#  'RN7SL71P',
#  'snoU13',
#  'C6ORF50',
#  'snoU13',
#  'snoU13',
#  'RMRPP2',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL175P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'SNORD45',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'SNORA2',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'SNORD45',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'FLJ20306',
#  'snoU13',
#  'snoU13',
#  'RN7SL365P',
#  'snoU13',
#  'snoU13',
#  'PP13004',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL64P',
#  'snoU13',
#  'RN7SL816P',
#  'RN7SL855P',
#  'snoU13',
#  'snoU13',
#  'RN7SL642P',
#  'snoU13',
#  'RN7SL212P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL13P',
#  'snoU13',
#  'snoU13',
#  'RN7SL161P',
#  'snoU109',
#  'FLJ00325',
#  'snoU13',
#  'TSRM',
#  'snoZ185',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL207P',
#  'snoU13',
#  'snoU13',
#  'RN7SL142P',
#  'RN7SL872P',
#  'LRLE1',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'FP15737',
#  'RN7SL651P',
#  'snoU13',
#  'RN7SL781P',
#  'RN7SKP201',
#  'SNORD38',
#  'snoU13',
#  'RN7SKP41',
#  'SNORA7',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL777P',
#  'snoU13',
#  'snoU13',
#  'MIR1273A',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL590P',
#  'RN7SL412P',
#  'snoU13',
#  'C9orf38',
#  'snoU13',
#  'RN7SL157P',
#  'RN7SL158P',
#  'snoU13',
#  'snoU13',
#  'GVQW1',
#  'FLJ00273',
#  'RN7SL463P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'DKFZP434H0512',
#  'PALM2',
#  'AKAP2',
#  'snoU13',
#  'RN7SL227P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'SNORA14',
#  'DKFZP667F0711',
#  'snoU13',
#  'RN7SL232P',
#  'SNORD45',
#  'snoU13',
#  'snoU13',
#  'snoR442',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'C10orf43',
#  'FAM21D',
#  'RMRPP4',
#  'snoU13',
#  'snoU13',
#  'snoR442',
#  'snoU13',
#  'LINC00849',
#  'snoU13',
#  'RN7SL373P',
#  'snoU13',
#  'SNORA36',
#  'snoU13',
#  'RMRPP1',
#  'RN7SKP84',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'HUG1',
#  'snoU13',
#  'RN7SL21P',
#  'snoU13',
#  'RN7SL450P',
#  'snoU13',
#  'RN7SL686P',
#  'snoU13',
#  'snoU13',
#  'SNORA7',
#  'RN7SL56P',
#  'snoU13',
#  'RN7SL772P',
#  'snoU13',
#  'snoU13',
#  'RN7SL119P',
#  'RN7SL114P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL59P',
#  'snoU13',
#  'SNORA7',
#  'DKFZP434E1119',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL195P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snosnR66',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL86P',
#  'RN7SL529P',
#  'MIR3656',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL852P',
#  'SNORD88',
#  'RN7SL46P',
#  'snoU13',
#  'snoU13',
#  'RN7SL10P',
#  'DKFZP779L1853',
#  'snoU13',
#  'RN7SL770P',
#  'HBCBP',
#  'RN7SL312P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL696P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL179P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'SNORD50',
#  'snoU13',
#  'RN7SL133P',
#  'MIR4419B',
#  'snoU13',
#  'RN7SL534P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL80P',
#  'snoU13',
#  'RN7SL289P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RNA5SP32',
#  'SNORD38',
#  'snoU13',
#  'snR65',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'LINC00283',
#  'snoU13',
#  'snoU13',
#  'RNA5SP381',
#  'snoU13',
#  'snoU13',
#  'snoU83B',
#  'RN7SL588P',
#  'RN7SL540P',
#  'RN7SL224P',
#  'snoU13',
#  'snoU13',
#  'SNORA7',
#  'RN7SL747P',
#  'RN7SL137P',
#  'snoU13',
#  'RN7SL506P',
#  'DKFZP434O1614',
#  'snoU13',
#  'RN7SL710P',
#  'SNORD113',
#  'SNORD113',
#  'SNORD113',
#  'SNORD113',
#  'SNORD113',
#  'SNORD113',
#  'snoU13',
#  'snoU13',
#  'DKFZP547L112',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL829P',
#  'snoZ278',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL347P',
#  'snoU13',
#  'FKSG62',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'C15ORF31',
#  'snoU13',
#  'RN7SL613P',
#  'RN7SL595P',
#  'RN7SL707P',
#  'RN7SL348P',
#  'snoU13',
#  'snoU13',
#  'RNA5SP398',
#  'RN7SL485P',
#  'CSPG4P8',
#  'RN7SL256P',
#  'RN7SL410P',
#  'RN7SL61P',
#  'RN7SL755P',
#  'snoU13',
#  'snoU109',
#  'RN7SL599P',
#  'DKFZP779J2370',
#  'snoU13',
#  'RN7SL367P',
#  'RN7SL99P',
#  'snoU13',
#  'snoU13',
#  'RN7SL522P',
#  'RN7SL90P',
#  'snoU13',
#  'RN7SL245P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL54P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU109',
#  'snoU109',
#  'snoU13',
#  'FKSG63',
#  'snoU13',
#  'RN7SL407P',
#  'FLJ00418',
#  'snoU13',
#  'snoU13',
#  'FLJ00104',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL171P',
#  'snoU13',
#  'snoU13',
#  'MIR3676',
#  'RN7SL129P',
#  'RN7SL550P',
#  'snoU13',
#  'snoU13',
#  'RN7SL639P',
#  'RN7SL17P',
#  'RN7SL576P',
#  'Vault',
#  'snoU13',
#  'snoU13',
#  'Vault',
#  'RN7SKP274',
#  'RN7SL458P',
#  'RN7SL102P',
#  'RN7SL871P',
#  'RN7SL730P',
#  'RN7SL739P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL699P',
#  'snoZ178',
#  'RN7SL437P',
#  'snoU13',
#  'RN7SL805P',
#  'RN7SL409P',
#  'snoU13',
#  'SCARNA24',
#  'snoU13',
#  'FLJ45079',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU109',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snR65',
#  'RN7SL723P',
#  'RN7SL537P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL662P',
#  'snoU13',
#  'snoU13',
#  'RN7SL247P',
#  'snoU13',
#  'snoU13',
#  'RN7SL695P',
#  'snoU13',
#  'RN7SL112P',
#  'snoU13',
#  'RN7SL226P',
#  'RN7SL866P',
#  'SNORD38',
#  'RN7SL84P',
#  'RN7SL528P',
#  'RN7SL626P',
#  'RN7SL115P',
#  'RN7SL94P',
#  'RN7SL298P',
#  'DKFZP761J1410',
#  'snoU13',
#  'RN7SL669P',
#  'RN7SL844P',
#  'snoU13',
#  'RN7SL765P',
#  'RN7SL287P',
#  'snoU13',
#  'snoU13',
#  'RN7SL758P',
#  'RN7SL53P',
#  'snoZ6',
#  'snoU13',
#  'RN7SL533P',
#  'RN7SL345P',
#  'RN7SL324P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL839P',
#  'snoU13',
#  'RN7SL514P',
#  'snoR26',
#  'RN7SL511P',
#  'snoU13',
#  'snoU13',
#  'RN7SL194P',
#  'RN7SL31P',
#  'RN7SL243P',
#  'snoU13',
#  'RN7SL603P',
#  'snoU13',
#  'MIR4532',
#  'MIR3687',
#  'snoU13',
#  'RN7SL609P',
#  'snoU13',
#  'snoU13',
#  'RN7SL109P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoZ6',
#  'snoZ6',
#  'PRED58',
#  'PRED60',
#  'PRED62',
#  'snoU13',
#  'RN7SL389P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'MGC20647',
#  'snoU13',
#  'RN7SL349P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'FLJ27365',
#  'RN7SL355P',
#  'snoU13',
#  'SNORA7',
#  'snoU13',
#  'RN7SL436P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL406P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL139P',
#  'RN7SL746P',
#  'snoU13',
#  'RN7SL264P',
#  'RN7SL641P',
#  'SNORD45',
#  'RN7SL661P',
#  'snoU13',
#  'snoU13',
#  'RN7SL29P',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'snoU13',
#  'RN7SL742P']

# %%
rna_df
# Out:
#          gene_id  TCGA-OR-A5J1-01A-11R-A29S-07  TCGA-OR-A5J2-01A-11R-A29S-07  \
# 0      100130426                        0.0000                        0.0000
# 1      100133144                        3.2661                        2.6815
# 2      100134869                        3.9385                        8.9948
# 3          10357                      149.1350                       81.0777
# 4          10431                     2034.1000                     1304.9300
# ...          ...                           ...                           ...
#        TCGA-CG-4472-01A-01R-1157-13  TCGA-CG-4474-01A-02R-1157-13  \
# 0                               NaN                           NaN
# 1                          6.997533                     18.311906
# 2                         13.654193                      7.417109
# 3                        639.238135                    742.479964
# 4                       1297.152549                   1152.909807
# ...                             ...                           ...
# 20526                      3.268489                     17.164493
# 20527                    905.046317                    757.811259
# 20528                   3359.241568                   4264.469081
# 20529                   1740.926312                   2702.668453
# 20530                   1148.217844                    857.336078
#
#        TCGA-CG-4475-01A-01R-1157-13  TCGA-CG-4476-01A-01R-1157-13  \
# 0                               NaN                           NaN
# 1                         12.057112                     18.628740
# 2                         11.585177                     11.482418
# 3                        506.336449                    712.452165
# 4                       1375.495774                    971.893874
# ...                             ...                           ...
# 20526                      3.756246                      0.301440
# 20527                    927.963540                    845.677334
# 20528                   3103.609391                   3302.569055
# 20529                   1370.141309                   1915.477072
# 20530                    473.853001                   1027.285482
#
#        TCGA-CG-4477-01A-01R-1157-13
# 0                               NaN
# 1                         17.874417
# 2                         14.919338
# 3                        703.713324
# 4                       1736.988111
# ...                             ...
# 20526                    217.431795
# 20527                    859.078048
# 20528                   2497.814797
# 20529                   1247.130940
# 20530                    916.155785
#
# [20531 rows x 11070 columns]

# %%
blca_cna_df
# Out:
#        TCGA-2F-A9KO-01  TCGA-2F-A9KP-01  TCGA-2F-A9KQ-01  TCGA-2F-A9KR-01  \
# 0               -0.235            0.575           -0.010           -0.073
# 1               -0.235            0.575           -0.010           -0.073
# 2               -0.235            0.575           -0.010           -0.073
# 3               -0.235            0.575           -0.010           -0.073
# 4               -0.235            0.575           -0.010           -0.073
# ...                ...              ...              ...              ...
# 24771            0.017           -0.087           -0.148           -0.103
# 24772            0.017           -0.087           -0.148           -0.103
# 24773            0.017           -0.087           -0.148           -0.103
# 24774            0.017           -0.087           -0.148           -0.103
# 24775            0.017           -0.087           -0.148           -0.103
#
#        TCGA-2F-A9KT-01  TCGA-2F-A9KW-01  TCGA-4Z-AA7M-01  TCGA-4Z-AA7N-01  \
# 0               -0.037           -0.842            0.031            0.029
# 1               -0.037           -0.842            0.031            0.029
# 2               -0.037           -0.842            0.031            0.029
# 3               -0.037           -0.842            0.031            0.029
# 4               -0.037           -0.842            0.031            0.029
# ...                ...              ...              ...              ...
# 24771           -0.128            0.542            0.511            0.031
# 24772           -0.128            0.542            0.511            0.031
# 24773           -0.128            0.542            0.511            0.031
# 24774           -0.128            0.542            0.511            0.031
# 24775           -0.128            0.542            0.511            0.031
#
#        TCGA-4Z-AA7O-01  TCGA-4Z-AA7Q-01  ...  TCGA-ZF-AA52-01  \
# 0                0.002           -0.038  ...            0.337
# 1                0.002           -0.038  ...            0.337
# 2                0.002           -0.038  ...            0.337
# 3                0.002           -0.038  ...            0.337
# 4                0.002           -0.038  ...            0.337
# ...                ...              ...  ...              ...
# 24771           -0.123           -0.020  ...            0.069
# 24772           -0.123           -0.020  ...            0.069
# 24773           -0.123           -0.020  ...            0.069
# 24774           -0.123           -0.020  ...            0.069
# 24775           -0.123           -0.020  ...            0.069
#
#        TCGA-ZF-AA53-01  TCGA-ZF-AA54-01  TCGA-ZF-AA56-01  TCGA-ZF-AA58-01  \
# 0                0.242           -0.366            0.009            0.040
# 1                0.242           -0.366            0.009            0.040
# 2                0.242           -0.366            0.009            0.040
# 3                0.242           -0.366            0.009            0.040
# 4                0.242           -0.366            0.009            0.040
# ...                ...              ...              ...              ...
# 24771            0.001            0.025            0.037            0.086
# 24772            0.001            0.025            0.037            0.086
# 24773            0.001            0.025            0.037            0.086
# 24774            0.001            0.025            0.037            0.086
# 24775            0.001            0.025            0.037            0.086
#
#        TCGA-ZF-AA5H-01  TCGA-ZF-AA5N-01  TCGA-ZF-AA5P-01  entrezgene_id  \
# 0                0.117           -0.018           -0.056   1.169830e+05
# 1                0.117           -0.018           -0.056   1.406250e+05
# 2                0.117           -0.018           -0.056   3.757900e+05
# 3                0.117           -0.018           -0.056   4.418690e+05
# 4                0.117           -0.018           -0.056   5.521000e+04
# ...                ...              ...              ...            ...
# 24771            0.217            0.056            0.003   3.581000e+03
# 24772            0.217            0.056            0.003   1.025100e+04
# 24773            0.217            0.056            0.003   6.845000e+03
# 24774            0.217            0.056            0.003  -2.147484e+09
# 24775            0.217            0.056            0.003  -2.147484e+09
#
#                ensembl_id
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 24771  ENSG00000124334.12
# 24772   ENSG00000168939.6
# 24773  ENSG00000124333.10
# 24774  ENSG00000182484.10
# 24775   ENSG00000185203.7
#
# [24776 rows x 410 columns]

# %%
lusc_cna_df
# Out:
#        TCGA-18-3406-01  TCGA-18-3407-01  TCGA-18-3408-01  TCGA-18-3409-01  \
# 0                0.284           -0.083           -0.775            -0.13
# 1                0.284           -0.083           -0.775            -0.13
# 2                0.284           -0.083           -0.775            -0.13
# 3                0.284           -0.083           -0.775            -0.13
# 4                0.284           -0.083           -0.775            -0.13
# ...                ...              ...              ...              ...
# 24771           -0.258            0.249            0.319             0.00
# 24772           -0.258            0.249            0.319             0.00
# 24773           -0.258            0.249            0.319             0.00
# 24774           -0.258            0.249            0.319             0.00
# 24775           -0.258            0.249            0.319             0.00
#
#        TCGA-18-3410-01  TCGA-18-3411-01  TCGA-18-3412-01  TCGA-18-3414-01  \
# 0               -0.004           -0.458            0.109           -0.132
# 1               -0.004           -0.458            0.109           -0.132
# 2               -0.004           -0.458            0.109           -0.132
# 3               -0.004           -0.458            0.109           -0.132
# 4               -0.004           -0.458            0.109           -0.132
# ...                ...              ...              ...              ...
# 24771            0.019            0.013           -0.502            0.080
# 24772            0.019            0.013           -0.502            0.080
# 24773            0.019            0.013           -0.502            0.080
# 24774            0.019            0.013           -0.502            0.080
# 24775            0.019            0.013           -0.502            0.080
#
#        TCGA-18-3415-01  TCGA-18-3416-01  ...  TCGA-NK-A7XE-01  \
# 0               -0.339            0.049  ...            0.094
# 1               -0.339            0.049  ...            0.094
# 2               -0.339            0.049  ...            0.094
# 3               -0.339            0.049  ...            0.094
# 4               -0.339            0.049  ...            0.094
# ...                ...              ...  ...              ...
# 24771            0.241           -0.237  ...            0.254
# 24772            0.241           -0.237  ...            0.254
# 24773            0.241           -0.237  ...            0.254
# 24774            0.241           -0.237  ...            0.254
# 24775            0.241           -0.237  ...            0.254
#
#        TCGA-O2-A52N-01  TCGA-O2-A52Q-01  TCGA-O2-A52S-01  TCGA-O2-A52V-01  \
# 0               -0.375           -0.438           -0.634           -0.134
# 1               -0.375           -0.438           -0.634           -0.134
# 2               -0.375           -0.438           -0.634           -0.134
# 3               -0.375           -0.438           -0.634           -0.134
# 4               -0.375           -0.438           -0.634           -0.134
# ...                ...              ...              ...              ...
# 24771           -0.047            0.474           -0.175           -0.394
# 24772           -0.047            0.474           -0.175           -0.394
# 24773           -0.047            0.474           -0.175           -0.394
# 24774           -0.047            0.474           -0.175           -0.394
# 24775           -0.047            0.474           -0.175           -0.394
#
#        TCGA-O2-A52W-01  TCGA-O2-A5IB-01  TCGA-XC-AA0X-01  entrezgene_id  \
# 0                0.008            0.973            0.073   1.169830e+05
# 1                0.008            0.973            0.073   1.406250e+05
# 2                0.008            0.973            0.073   3.757900e+05
# 3                0.008            0.973            0.073   4.418690e+05
# 4                0.008            0.973            0.073   5.521000e+04
# ...                ...              ...              ...            ...
# 24771            0.051            1.121            0.008   3.581000e+03
# 24772            0.051            1.121            0.008   1.025100e+04
# 24773            0.051            1.121            0.008   6.845000e+03
# 24774            0.051            1.121            0.008  -2.147484e+09
# 24775            0.051            1.121            0.008  -2.147484e+09
#
#                ensembl_id
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 24771  ENSG00000124334.12
# 24772   ENSG00000168939.6
# 24773  ENSG00000124333.10
# 24774  ENSG00000182484.10
# 24775   ENSG00000185203.7
#
# [24776 rows x 503 columns]

# %%
ov_cna_df
# Out:
#        TCGA-04-1331-01  TCGA-04-1332-01  TCGA-04-1335-01  TCGA-04-1336-01  \
# 0               -0.703            0.080           -0.807            0.101
# 1               -0.703            0.080           -0.807            0.101
# 2               -0.703            0.080           -0.807            0.101
# 3               -0.703            0.080           -0.807            0.101
# 4               -0.703            0.080           -0.807            0.101
# ...                ...              ...              ...              ...
# 24771           -0.368           -0.256            0.673           -0.336
# 24772           -0.368           -0.256            0.673           -0.336
# 24773           -0.368           -0.256            0.673           -0.336
# 24774           -0.368           -0.256            0.673           -0.336
# 24775           -0.368           -0.256            0.673           -0.336
#
#        TCGA-04-1337-01  TCGA-04-1338-01  TCGA-04-1341-01  TCGA-04-1342-01  \
# 0                0.021           -0.999           -0.421            0.089
# 1                0.021           -0.999           -0.421            0.089
# 2                0.021           -0.999           -0.421            0.089
# 3                0.021           -0.999           -0.421            0.089
# 4                0.021           -0.999           -0.421            0.089
# ...                ...              ...              ...              ...
# 24771            0.062           -0.082           -0.589            0.136
# 24772            0.062           -0.082           -0.589            0.136
# 24773            0.062           -0.082           -0.589            0.136
# 24774            0.062           -0.082           -0.589            0.136
# 24775            0.062           -0.082           -0.589            0.136
#
#        TCGA-04-1343-01  TCGA-04-1346-01  ...  TCGA-72-4237-01  \
# 0                0.279           -0.396  ...            0.801
# 1                0.279           -0.396  ...            0.801
# 2                0.279           -0.396  ...            0.801
# 3                0.279           -0.396  ...            0.801
# 4                0.279           -0.396  ...            0.801
# ...                ...              ...  ...              ...
# 24771            0.187            0.356  ...           -0.143
# 24772            0.187            0.356  ...           -0.143
# 24773            0.187            0.356  ...           -0.143
# 24774            0.187            0.356  ...           -0.143
# 24775            0.187            0.356  ...           -0.143
#
#        TCGA-72-4238-01  TCGA-72-4240-01  TCGA-72-4241-01  TCGA-OY-A56P-01  \
# 0                 0.04            0.058            0.339            0.813
# 1                 0.04            0.058            0.339            0.813
# 2                 0.04            0.058            0.339            0.813
# 3                 0.04            0.058            0.339            0.813
# 4                 0.04            0.058            0.339            0.813
# ...                ...              ...              ...              ...
# 24771            -0.21           -0.349           -0.100           -0.080
# 24772            -0.21           -0.349           -0.100           -0.080
# 24773            -0.21           -0.349           -0.100           -0.080
# 24774            -0.21           -0.349           -0.100           -0.080
# 24775            -0.21           -0.349           -0.100           -0.080
#
#        TCGA-OY-A56Q-01  TCGA-VG-A8LO-01  TCGA-WR-A838-01  entrezgene_id  \
# 0                0.000            0.137           -0.176   1.169830e+05
# 1                0.000            0.137           -0.176   1.406250e+05
# 2                0.000            0.137           -0.176   3.757900e+05
# 3                0.000            0.137           -0.176   4.418690e+05
# 4                0.000            0.137           -0.176   5.521000e+04
# ...                ...              ...              ...            ...
# 24771           -0.195           -0.675            0.065   3.581000e+03
# 24772           -0.195           -0.675            0.065   1.025100e+04
# 24773           -0.195           -0.675            0.065   6.845000e+03
# 24774           -0.195           -0.675            0.065  -2.147484e+09
# 24775           -0.195           -0.675            0.065  -2.147484e+09
#
#                ensembl_id
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 24771  ENSG00000124334.12
# 24772   ENSG00000168939.6
# 24773  ENSG00000124333.10
# 24774  ENSG00000182484.10
# 24775   ENSG00000185203.7
#
# [24776 rows x 581 columns]

# %% [markdown]
# # Number of OV samples which occurs both in ov_subtype_info and rna_data

# %%
import os
import pandas as pd

data_dir = "../data"
raw_folder_name = "raw"
rna_data_file_name = "EBPlusPlusAdjustPANCAN_IlluminaHiSeq_RNASeqV2.geneExp.tsv"

rna_df = pd.read_csv(os.path.join(data_dir, raw_folder_name, rna_data_file_name), sep="\t")

ov_subtype_info_file_name = "ov_subtype_info.tsv"
ov_subtype_info_df = pd.read_csv(os.path.join(data_dir, raw_folder_name, ov_subtype_info_file_name), sep="\t")

len(set([column[:15] for column in rna_df.columns if column != "gene_id"]).intersection(set(ov_subtype_info_df.ID)))
# Out:
# 295

# %%
import os
import pandas as pd

data_dir = "../data"
raw_folder_name = "raw"
rna_data_file_name = "EBPlusPlusAdjustPANCAN_IlluminaHiSeq_RNASeqV2.geneExp.tsv"

rna_df = pd.read_csv(os.path.join(data_dir, raw_folder_name, rna_data_file_name), sep="\t")

cna_file_name = "TCGA.LUSC.sampleMap_Gistic2_CopyNumber_Gistic2_all_data_by_genes"
cna_df = pd.read_csv(os.path.join(data_dir, raw_folder_name, cna_file_name), sep="\t")

# ov_subtype_info_file_name = "o_subtype_info.tsv"
# ov_subtype_info_df = pd.read_csv(os.path.join(data_dir, raw_folder_name, ov_subtype_info_file_name), sep="\t")

# len(set([column[:15] for column in rna_df.columns if column != "gene_id"]).intersection(set(ov_subtype_info_df.ID)))

# %%
rna_df
# Out:
#              gene_id  TCGA-OR-A5J1-01A-11R-A29S-07  \
# 0        ?|100130426                        0.0000
# 1        ?|100133144                        3.2661
# 2        ?|100134869                        3.9385
# 3            ?|10357                      149.1350
# 4            ?|10431                     2034.1000
# ...              ...                           ...
# 20526  ZYG11A|440590                        0.4803
# 20527   ZYG11B|79699                      648.4150
# 20528       ZYX|7791                     1841.0200
# 20529    ZZEF1|23140                     1157.5400
# 20530     ZZZ3|26009                      596.0620
#
#        TCGA-OR-A5J2-01A-11R-A29S-07  TCGA-OR-A5J3-01A-11R-A29S-07  \
# 0                            0.0000                        0.0000
# 1                            2.6815                        1.7301
# 2                            8.9948                        6.5650
# 3                           81.0777                       86.4879
# 4                         1304.9300                     1054.6600
# ...                             ...                           ...
# 20526                       31.4052                        0.5925
# 20527                     1166.0200                      806.3990
# 20528                     3059.9900                     2655.6100
# 20529                     1895.9900                     1482.4500
# 20530                      801.6370                      437.2690
#
#        TCGA-OR-A5J5-01A-11R-A29S-07  TCGA-OR-A5J6-01A-31R-A29S-07  \
# 0                            0.0000                        0.0000
# 1                            0.0000                        0.0000
# 2                            1.5492                        4.4709
# 3                           53.9117                       66.9063
# 4                         2350.8900                     1257.9900
# ...                             ...                           ...
# 20526                       11.6189                        7.8240
# 20527                      553.8340                      795.8120
# 20528                     2367.9300                      708.0710
# 20529                     1140.2000                      796.3710
# 20530                      512.7810                      475.5870
#
#        TCGA-OR-A5J7-01A-11R-A29S-07  TCGA-OR-A5J8-01A-11R-A29S-07  \
# 0                            0.0000                        0.0000
# 1                            1.1673                        1.4422
# 2                            6.0529                        2.2876
# 3                          103.5060                       94.9316
# 4                         1866.4300                      995.0270
# ...                             ...                           ...
# 20526                       85.4392                        0.4144
# 20527                      520.6580                      556.1540
# 20528                      855.1940                    10924.6000
# 20529                      897.7140                     1095.7300
# 20530                      397.1120                      462.0800
#
#        TCGA-OR-A5J9-01A-11R-A29S-07  TCGA-OR-A5JA-01A-11R-A29S-07  ...  \
# 0                            0.0000                        0.0000  ...
# 1                            0.0000                        4.4556  ...
# 2                            1.3599                        5.0581  ...
# 3                           78.1955                       69.2389  ...
# 4                         1762.1200                     1213.5300  ...
# ...                             ...                           ...  ...
# 20526                        2.3799                        1.0571  ...
# 20527                      913.1870                      805.4970  ...
# 20528                     2122.1600                     1939.2200  ...
# 20529                     1003.6200                      904.8630  ...
# 20530                      642.2230                      542.8120  ...
#
#        TCGA-CG-4449-01A-01R-1157-13  TCGA-CG-4462-01A-01R-1157-13  \
# 0                               NaN                           NaN
# 1                          4.358154                      5.676995
# 2                          2.656360                      3.342794
# 3                        633.299781                    294.018042
# 4                       1202.538277                    644.002317
# ...                             ...                           ...
# 20526                     20.923873                      1.839530
# 24772            0.319             0.00            0.019            0.013
# 24773            0.319             0.00            0.019            0.013
# 24774            0.319             0.00            0.019            0.013
# 24775            0.319             0.00            0.019            0.013
#
#        TCGA-18-3412-01  TCGA-18-3414-01  TCGA-18-3415-01  ...  \
# 0                0.109           -0.132           -0.339  ...
# 1                0.109           -0.132           -0.339  ...
# 2                0.109           -0.132           -0.339  ...
# 3                0.109           -0.132           -0.339  ...
# 4                0.109           -0.132           -0.339  ...
# ...                ...              ...              ...  ...
# 24771           -0.502            0.080            0.241  ...
# 24772           -0.502            0.080            0.241  ...
# 24773           -0.502            0.080            0.241  ...
# 24774           -0.502            0.080            0.241  ...
# 24775           -0.502            0.080            0.241  ...
#
#        TCGA-NK-A5CX-01  TCGA-NK-A5D1-01  TCGA-NK-A7XE-01  TCGA-O2-A52N-01  \
# 0                0.043            0.021            0.094           -0.375
# 1                0.043            0.021            0.094           -0.375
# 2                0.043            0.021            0.094           -0.375
# 3                0.043            0.021            0.094           -0.375
# 4                0.043            0.021            0.094           -0.375
# ...                ...              ...              ...              ...
# 24771            0.044           -0.447            0.254           -0.047
# 24772            0.044           -0.447            0.254           -0.047
# 24773            0.044           -0.447            0.254           -0.047
# 24774            0.044           -0.447            0.254           -0.047
# 24775            0.044           -0.447            0.254           -0.047
#
#        TCGA-O2-A52Q-01  TCGA-O2-A52S-01  TCGA-O2-A52V-01  TCGA-O2-A52W-01  \
# 0               -0.438           -0.634           -0.134            0.008
# 1               -0.438           -0.634           -0.134            0.008
# 2               -0.438           -0.634           -0.134            0.008
# 3               -0.438           -0.634           -0.134            0.008
# 4               -0.438           -0.634           -0.134            0.008
# ...                ...              ...              ...              ...
# 24771            0.474           -0.175           -0.394            0.051
# 24772            0.474           -0.175           -0.394            0.051
# 24773            0.474           -0.175           -0.394            0.051
# 24774            0.474           -0.175           -0.394            0.051
# 24775            0.474           -0.175           -0.394            0.051
#
#        TCGA-O2-A5IB-01  TCGA-XC-AA0X-01
# 0                0.973            0.073
# 1                0.973            0.073
# 2                0.973            0.073
# 3                0.973            0.073
# 4                0.973            0.073
# ...                ...              ...
# 24771            1.121            0.008
# 24772            1.121            0.008
# 24773            1.121            0.008
# 24774            1.121            0.008
# 24775            1.121            0.008
#
# [24776 rows x 502 columns]

# %%
rna_df
# Out:
#              gene_id  TCGA-OR-A5J1-01A-11R-A29S-07  \
# 0        ?|100130426                        0.0000
# 1        ?|100133144                        3.2661
# 2        ?|100134869                        3.9385
# 3            ?|10357                      149.1350
# 4            ?|10431                     2034.1000
# ...              ...                           ...
# 20526  ZYG11A|440590                        0.4803
# 20527   ZYG11B|79699                      648.4150
# 20528       ZYX|7791                     1841.0200
# 20529    ZZEF1|23140                     1157.5400
# 20530     ZZZ3|26009                      596.0620
#
#        TCGA-OR-A5J2-01A-11R-A29S-07  TCGA-OR-A5J3-01A-11R-A29S-07  \
# 0                            0.0000                        0.0000
# 1                            2.6815                        1.7301
# 2                            8.9948                        6.5650
# 3                           81.0777                       86.4879
# 4                         1304.9300                     1054.6600
# ...                             ...                           ...
#        TCGA-CG-4474-01A-02R-1157-13  TCGA-CG-4475-01A-01R-1157-13  \
# 0                               NaN                           NaN
# 1                         18.311906                     12.057112
# 2                          7.417109                     11.585177
# 3                        742.479964                    506.336449
# 4                       1152.909807                   1375.495774
# ...                             ...                           ...
# 20526                     17.164493                      3.756246
# 20527                    757.811259                    927.963540
# 20528                   4264.469081                   3103.609391
# 20529                   2702.668453                   1370.141309
# 20530                    857.336078                    473.853001
#
#        TCGA-CG-4476-01A-01R-1157-13  TCGA-CG-4477-01A-01R-1157-13
# 0                               NaN                           NaN
# 1                         18.628740                     17.874417
# 2                         11.482418                     14.919338
# 3                        712.452165                    703.713324
# 4                        971.893874                   1736.988111
# ...                             ...                           ...
# 20526                      0.301440                    217.431795
# 20527                    845.677334                    859.078048
# 20528                   3302.569055                   2497.814797
# 20529                   1915.477072                   1247.130940
# 20530                   1027.285482                    916.155785
#
# [20531 rows x 11070 columns]

# %%
import os
import pandas as pd

data_dir = "../data"
raw_folder_name = "raw"

ov_cna_file_name = "TCGA.OV.sampleMap_Gistic2_CopyNumber_Gistic2_all_data_by_genes"
ov_cna_df = pd.read_csv(os.path.join(data_dir, raw_folder_name, ov_cna_file_name), sep="\t")

len(set([column[:15] for column in rna_df.columns if column != "gene_id"]).intersection(set([column for column in ov_cna_df.columns if column != "Gene Symbol"])))
# Out:
# 301

# %%
ov_cna_df
# Out:
#                      Gene Symbol  TCGA-04-1331-01  TCGA-04-1332-01  \
# 0                          ACAP3           -0.703            0.080
# 1                         ACTRT2           -0.703            0.080
# 2                           AGRN           -0.703            0.080
# 3                        ANKRD65           -0.703            0.080
# 4                         ATAD3A           -0.703            0.080
# ...                          ...              ...              ...
# 24771    IL9R|ENSG00000124334.12           -0.368           -0.256
# 24772    SPRY3|ENSG00000168939.6           -0.368           -0.256
# 24773   VAMP7|ENSG00000124333.10           -0.368           -0.256
# 24774  WASH6P|ENSG00000182484.10           -0.368           -0.256
# 24775   WASIR1|ENSG00000185203.7           -0.368           -0.256
#
#        TCGA-04-1335-01  TCGA-04-1336-01  TCGA-04-1337-01  TCGA-04-1338-01  \
# 0               -0.807            0.101            0.021           -0.999
# 1               -0.807            0.101            0.021           -0.999
# 2               -0.807            0.101            0.021           -0.999
# 3               -0.807            0.101            0.021           -0.999
# 4               -0.807            0.101            0.021           -0.999
# ...                ...              ...              ...              ...
# 24771            0.673           -0.336            0.062           -0.082
# 24772            0.673           -0.336            0.062           -0.082
# 24773            0.673           -0.336            0.062           -0.082
# 24774            0.673           -0.336            0.062           -0.082
# 24775            0.673           -0.336            0.062           -0.082
#
#        TCGA-04-1341-01  TCGA-04-1342-01  TCGA-04-1343-01  ...  \
# 0               -0.421            0.089            0.279  ...
# 1               -0.421            0.089            0.279  ...
# 2               -0.421            0.089            0.279  ...
# 3               -0.421            0.089            0.279  ...
# 4               -0.421            0.089            0.279  ...
# ...                ...              ...              ...  ...
# 24771           -0.589            0.136            0.187  ...
# 24772           -0.589            0.136            0.187  ...
# 24773           -0.589            0.136            0.187  ...
# 24774           -0.589            0.136            0.187  ...
# 24775           -0.589            0.136            0.187  ...
#
#        TCGA-72-4235-01  TCGA-72-4236-01  TCGA-72-4237-01  TCGA-72-4238-01  \
# 0               -0.076            0.054            0.801             0.04
# 1               -0.076            0.054            0.801             0.04
# 2               -0.076            0.054            0.801             0.04
# 3               -0.076            0.054            0.801             0.04
# 4               -0.076            0.054            0.801             0.04
# ...                ...              ...              ...              ...
# 24771           -0.081           -0.216           -0.143            -0.21
# 24772           -0.081           -0.216           -0.143            -0.21
# 24773           -0.081           -0.216           -0.143            -0.21
# 24774           -0.081           -0.216           -0.143            -0.21
# 24775           -0.081           -0.216           -0.143            -0.21
#
#        TCGA-72-4240-01  TCGA-72-4241-01  TCGA-OY-A56P-01  TCGA-OY-A56Q-01  \
# 0                0.058            0.339            0.813            0.000
# 1                0.058            0.339            0.813            0.000
# 2                0.058            0.339            0.813            0.000
# 3                0.058            0.339            0.813            0.000
# 4                0.058            0.339            0.813            0.000
# ...                ...              ...              ...              ...
# 24771           -0.349           -0.100           -0.080           -0.195
# 24772           -0.349           -0.100           -0.080           -0.195
# 24773           -0.349           -0.100           -0.080           -0.195
# 24774           -0.349           -0.100           -0.080           -0.195
# 24775           -0.349           -0.100           -0.080           -0.195
#
#        TCGA-VG-A8LO-01  TCGA-WR-A838-01
# 0                0.137           -0.176
# 1                0.137           -0.176
# 2                0.137           -0.176
# 3                0.137           -0.176
# 4                0.137           -0.176
# ...                ...              ...
# 24771           -0.675            0.065
# 24772           -0.675            0.065
# 24773           -0.675            0.065
# 24774           -0.675            0.065
# 24775           -0.675            0.065
#
# [24776 rows x 580 columns]

# %%
ov_subtype_info_file_name = "ov_subtype_info.tsv"
ov_subtype_info = pd.read_csv(os.path.join(data_dir, raw_folder_name, ov_subtype_info_file_name), sep="\t")
len(set(ov_subtype_info.ID))

# %%
import os
import pandas as pd

data_dir = "../data"
raw_folder_name = "raw"
cancer_type_raw_cna_file_name_map = {
    "BLCA": "TCGA.BLCA.sampleMap_Gistic2_CopyNumber_Gistic2_all_data_by_genes",
    "LUSC": "TCGA.LUSC.sampleMap_Gistic2_CopyNumber_Gistic2_all_data_by_genes",
    "OV": "TCGA.OV.sampleMap_Gistic2_CopyNumber_Gistic2_all_data_by_genes"
}
cancer_type = "OV"
cancer_specific_cna_file_name = cancer_type_raw_cna_file_name_map[cancer_type]
df = pd.read_csv(os.path.join(data_dir, raw_folder_name, cancer_specific_cna_file_name), sep="\t")

# %%
import os
import numpy as np
import pandas as pd

data_dir = "../data"
raw_folder_name = "raw"

tumor_sample_ids = ["0" + str(i) for i in range(1, 10)]

cancer_type_raw_cna_file_name_map = {
    "BLCA": "TCGA.BLCA.sampleMap_Gistic2_CopyNumber_Gistic2_all_data_by_genes",
    "LUSC": "TCGA.LUSC.sampleMap_Gistic2_CopyNumber_Gistic2_all_data_by_genes",
    "OV": "TCGA.OV.sampleMap_Gistic2_CopyNumber_Gistic2_all_data_by_genes"
}

cancer_type = "BLCA"
cancer_specific_cna_file_name = cancer_type_raw_cna_file_name_map[cancer_type]
cna_df = pd.read_csv(os.path.join(data_dir, raw_folder_name, cancer_specific_cna_file_name), sep="\t")

# %%
def select_the_ensemble_id_with_maximum_gene_expression(x):
    x_copy = x.drop(columns=["ensembl_id"])
    x_copy = 
    


def get_one_ensemble_id_per_gene(cna_df):
    cna_df_nan_ensemble_id = cna_df[pd.isnull(cna_df["ensemble_id"])]
    assert (cna_df_nan_ensemble_id.groupby("hgnc_symbol").count() != 1).sum() == 0
    cna_df_not_nan_ensemble_id = cna_df[~pd.isnull(cna_df["ensemble_id"])]
    cna_df_not_nan_ensemble_id = cna_df_not_nan_ensemble_id.groupby("hgnc_symbol").apply(lambda x: )
# Out:
#       hgnc_symbol  TCGA-2F-A9KO-01  TCGA-2F-A9KP-01  TCGA-2F-A9KQ-01  \
# 0           ACAP3           -0.235            0.575           -0.010
# 1          ACTRT2           -0.235            0.575           -0.010
# 2            AGRN           -0.235            0.575           -0.010
# 3         ANKRD65           -0.235            0.575           -0.010
# 4          ATAD3A           -0.235            0.575           -0.010
# ...           ...              ...              ...              ...
# 24771        IL9R            0.017           -0.087           -0.148
# 24772       SPRY3            0.017           -0.087           -0.148
# 24773       VAMP7            0.017           -0.087           -0.148
# 24774      WASH6P            0.017           -0.087           -0.148
# 24775      WASIR1            0.017           -0.087           -0.148
#
#        TCGA-2F-A9KR-01  TCGA-2F-A9KT-01  TCGA-2F-A9KW-01  TCGA-4Z-AA7M-01  \
# 0               -0.073           -0.037           -0.842            0.031
# 1               -0.073           -0.037           -0.842            0.031
# 2               -0.073           -0.037           -0.842            0.031
# 3               -0.073           -0.037           -0.842            0.031
# 4               -0.073           -0.037           -0.842            0.031
# ...                ...              ...              ...              ...
# 24771           -0.103           -0.128            0.542            0.511
# 24772           -0.103           -0.128            0.542            0.511
# 24773           -0.103           -0.128            0.542            0.511
# 24774           -0.103           -0.128            0.542            0.511
# 24775           -0.103           -0.128            0.542            0.511
#
#        TCGA-4Z-AA7N-01  TCGA-4Z-AA7O-01  ...  TCGA-ZF-AA51-01  \
# 0                0.029            0.002  ...            0.561
# 1                0.029            0.002  ...            0.561
# 2                0.029            0.002  ...            0.561
# 3                0.029            0.002  ...            0.561
# 4                0.029            0.002  ...            0.561
# ...                ...              ...  ...              ...
# 24771            0.031           -0.123  ...           -0.413
# 24772            0.031           -0.123  ...           -0.413
# 24773            0.031           -0.123  ...           -0.413
# 24774            0.031           -0.123  ...           -0.413
# 24775            0.031           -0.123  ...           -0.413
#
#        TCGA-ZF-AA52-01  TCGA-ZF-AA53-01  TCGA-ZF-AA54-01  TCGA-ZF-AA56-01  \
# 0                0.337            0.242           -0.366            0.009
# 1                0.337            0.242           -0.366            0.009
# 2                0.337            0.242           -0.366            0.009
# 3                0.337            0.242           -0.366            0.009
# 4                0.337            0.242           -0.366            0.009
# ...                ...              ...              ...              ...
# 24771            0.069            0.001            0.025            0.037
# 24772            0.069            0.001            0.025            0.037
# 24773            0.069            0.001            0.025            0.037
# 24774            0.069            0.001            0.025            0.037
# 24775            0.069            0.001            0.025            0.037
#
#        TCGA-ZF-AA58-01  TCGA-ZF-AA5H-01  TCGA-ZF-AA5N-01  TCGA-ZF-AA5P-01  \
# 0                0.040            0.117           -0.018           -0.056
# 1                0.040            0.117           -0.018           -0.056
# 2                0.040            0.117           -0.018           -0.056
# 3                0.040            0.117           -0.018           -0.056
# 4                0.040            0.117           -0.018           -0.056
# ...                ...              ...              ...              ...
# 24771            0.086            0.217            0.056            0.003
# 24772            0.086            0.217            0.056            0.003
# 24773            0.086            0.217            0.056            0.003
# 24774            0.086            0.217            0.056            0.003
# 24775            0.086            0.217            0.056            0.003
#
#                ensembl_id
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 24771  ENSG00000124334.12
# 24772   ENSG00000168939.6
# 24773  ENSG00000124333.10
# 24774  ENSG00000182484.10
# 24775   ENSG00000185203.7
#
# [24776 rows x 410 columns]

# %%
import os
import numpy as np
import pandas as pd

data_dir = "../data"
raw_folder_name = "raw"




def get_one_ensembl_id_per_gene():

# %%
cna_df
# Out:
#       hgnc_symbol  TCGA-2F-A9KO-01  TCGA-2F-A9KP-01  TCGA-2F-A9KQ-01  \
# 0           ACAP3           -0.235            0.575           -0.010
# 1          ACTRT2           -0.235            0.575           -0.010
# 2            AGRN           -0.235            0.575           -0.010
# 3         ANKRD65           -0.235            0.575           -0.010
# 4          ATAD3A           -0.235            0.575           -0.010
# ...           ...              ...              ...              ...
# 24771        IL9R            0.017           -0.087           -0.148
# 24772       SPRY3            0.017           -0.087           -0.148
# 24773       VAMP7            0.017           -0.087           -0.148
# 24774      WASH6P            0.017           -0.087           -0.148
# 24775      WASIR1            0.017           -0.087           -0.148
#
#        TCGA-2F-A9KR-01  TCGA-2F-A9KT-01  TCGA-2F-A9KW-01  TCGA-4Z-AA7M-01  \
# 0               -0.073           -0.037           -0.842            0.031
# 1               -0.073           -0.037           -0.842            0.031
# 2               -0.073           -0.037           -0.842            0.031
# 3               -0.073           -0.037           -0.842            0.031
# 4               -0.073           -0.037           -0.842            0.031
# ...                ...              ...              ...              ...
# 24771           -0.103           -0.128            0.542            0.511
# 24772           -0.103           -0.128            0.542            0.511
# 24773           -0.103           -0.128            0.542            0.511
# 24774           -0.103           -0.128            0.542            0.511
# 24775           -0.103           -0.128            0.542            0.511
#
#        TCGA-4Z-AA7N-01  TCGA-4Z-AA7O-01  ...  TCGA-ZF-AA51-01  \
# 0                0.029            0.002  ...            0.561
# 1                0.029            0.002  ...            0.561
# 2                0.029            0.002  ...            0.561
# 3                0.029            0.002  ...            0.561
# 4                0.029            0.002  ...            0.561
# ...                ...              ...  ...              ...
# 24771            0.031           -0.123  ...           -0.413
# 24772            0.031           -0.123  ...           -0.413
# 24773            0.031           -0.123  ...           -0.413
# 24774            0.031           -0.123  ...           -0.413
# 24775            0.031           -0.123  ...           -0.413
#
#        TCGA-ZF-AA52-01  TCGA-ZF-AA53-01  TCGA-ZF-AA54-01  TCGA-ZF-AA56-01  \
# 0                0.337            0.242           -0.366            0.009
# 1                0.337            0.242           -0.366            0.009
# 2                0.337            0.242           -0.366            0.009
# 3                0.337            0.242           -0.366            0.009
# 4                0.337            0.242           -0.366            0.009
# ...                ...              ...              ...              ...
# 24771            0.069            0.001            0.025            0.037
# 24772            0.069            0.001            0.025            0.037
# 24773            0.069            0.001            0.025            0.037
# 24774            0.069            0.001            0.025            0.037
# 24775            0.069            0.001            0.025            0.037
#
#        TCGA-ZF-AA58-01  TCGA-ZF-AA5H-01  TCGA-ZF-AA5N-01  TCGA-ZF-AA5P-01  \
# 0                0.040            0.117           -0.018           -0.056
# 1                0.040            0.117           -0.018           -0.056
# 2                0.040            0.117           -0.018           -0.056
# 3                0.040            0.117           -0.018           -0.056
# 4                0.040            0.117           -0.018           -0.056
# ...                ...              ...              ...              ...
# 24771            0.086            0.217            0.056            0.003
# 24772            0.086            0.217            0.056            0.003
# 24773            0.086            0.217            0.056            0.003
# 24774            0.086            0.217            0.056            0.003
# 24775            0.086            0.217            0.056            0.003
#
#                ensembl_id
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 24771  ENSG00000124334.12
# 24772   ENSG00000168939.6
# 24773  ENSG00000124333.10
# 24774  ENSG00000182484.10
# 24775   ENSG00000185203.7
#
# [24776 rows x 410 columns]

# %%
[column for column in cna_df.columns if column.split("-")[-1] != "01"]
# Out:
# ['Gene Symbol']

# %%
import os
import pandas as pd

cancer_type_raw_cna_file_name_map = {
    "BLCA": "TCGA.BLCA.sampleMap_Gistic2_CopyNumber_Gistic2_all_data_by_genes",
    "LUSC": "TCGA.LUSC.sampleMap_Gistic2_CopyNumber_Gistic2_all_data_by_genes",
    "OV": "TCGA.OV.sampleMap_Gistic2_CopyNumber_Gistic2_all_data_by_genes"
}

cancer_type = "BLCA"

cancer_specific_cna_file_name = cancer_type_raw_cna_file_name_map[cancer_type]
cna_df = pd.read_csv(os.path.join(data_dir, raw_folder_name, cancer_specific_cna_file_name), sep="\t")
cancer_specific_sample_ids = [column for column in cna_df.columns if column.split("-")[-1] in tumor_sample_ids]
cancer_specific_rna_df = rna_df[rna_df.index.map(lambda x: x[:15] in cancer_specific_sample_ids)]

# %%
cancer_specific_rna_df
# Out:
#                              100130426 100133144 100134869    10357    10431  \
# TCGA-2F-A9KO-01A-11R-A38B-07       0.0   20.4373   37.8717   123.09  702.041
# TCGA-2F-A9KP-01A-11R-A38B-07       0.0   16.1382   12.5759  137.886  882.231
# TCGA-2F-A9KQ-01A-11R-A38B-07       0.0   13.3333   10.7742  104.678  954.103
# TCGA-2F-A9KR-01A-11R-A38B-07       0.0   15.3523    42.581  146.453   487.21
# TCGA-2F-A9KT-01A-11R-A38B-07       0.0   14.0136   17.6427  142.962  954.777
# ...                                ...       ...       ...      ...      ...
# TCGA-ZF-AA56-01A-31R-A39I-07    0.4411    5.8271    7.8474  185.673   575.21
# TCGA-ZF-AA58-01A-12R-A42T-07    0.4216    1.7032    2.0911  210.181   1595.7
# TCGA-ZF-AA5H-01A-11R-A39I-07       0.0    3.3904    1.1387  186.938  1100.57
# TCGA-ZF-AA5N-01A-11R-A42T-07     1.227       0.0       0.0  155.301  1123.93
# TCGA-ZF-AA5N-01A-11R-A42T-07  15.9509  358.282  6306.75  850.307  380.368
# TCGA-ZF-AA5P-01A-11R-A39I-07  13.3407  887.715  14836.0  1030.02  1253.47
#
# [404 rows x 20531 columns]

# %%
import os
import pandas as pd

data_dir = "../data"
raw_folder_name = "raw"
processed_folder_name = "processed"
rna_file_name = "EBPlusPlusAdjustPANCAN_IlluminaHiSeq_RNASeqV2.geneExp.tsv"

rna_df = pd.read_csv(os.path.join(data_dir, raw_folder_name, rna_file_name), sep="\t")
rna_df["gene_id"] = rna_df["gene_id"].apply(lambda x: x.split("|")[1])
rna_df = rna_df.T
rna_df.columns = rna_df.loc["gene_id"].tolist()
rna_df = rna_df.drop("gene_id")

cancer_type_raw_cna_file_name_map = {
    "BLCA": "TCGA.BLCA.sampleMap_Gistic2_CopyNumber_Gistic2_all_data_by_genes",
    "LUSC": "TCGA.LUSC.sampleMap_Gistic2_CopyNumber_Gistic2_all_data_by_genes",
    "OV": "TCGA.OV.sampleMap_Gistic2_CopyNumber_Gistic2_all_data_by_genes"
}

cancer_type_id_mapping = {
    "BLCA": 0,
    "LUSC": 1,
    "OV": 2
}

tumor_sample_ids = ["0" + str(i) for i in range(1, 10)]

def get_cancer_specific_cna_df(cancer_type: str) -> pd.DataFrame:
    cancer_specific_cna_file_name = cancer_type_raw_cna_file_name_map[cancer_type]
    cna_df = pd.read_csv(os.path.join(data_dir, raw_folder_name, cancer_specific_cna_file_name), sep="\t")
    cancer_specific_sample_ids = [column for column in cna_df.columns if column.split("-")[-1] in tumor_sample_ids]
    cancer_specific_rna_df = rna_df[rna_df.index.map(lambda x: x[:15] in cancer_specific_sample_ids)]
    


def get_cancer_specific_rna_df(cancer_type: str) -> pd.DataFrame:
    cancer_specific_cna_file_name = cancer_type_raw_cna_file_name_map[cancer_type]
    cna_df = pd.read_csv(os.path.join(data_dir, raw_folder_name, cancer_specific_cna_file_name), sep="\t")
    cancer_specific_sample_ids = [column for column in cna_df.columns if column.split("-")[-1] in tumor_sample_ids]
    cancer_specific_rna_df = rna_df[rna_df.index.map(lambda x: x[:15] in cancer_specific_sample_ids)]
    
    sample_id_dict = {}
    for index in rna_df.index:
        index_first_15 = index[:15]
        if index_first_15 in sample_id_dict.keys():
            if index < sample_id_dict[index_first_15]:
                sample_id_dict[index_first_15] = index
            else:
                continue
        else:
            sample_id_dict[index_first_15] = index
    
    cancer_specific_rna_df = cancer_specific_rna_df[cancer_specific_rna_df.index.map(lambda x: x in sample_id_dict.values())]
    cancer_specific_rna_df.index = cancer_specific_rna_df.index.map(lambda x: x[:15])
    cancer_specific_id = cancer_type_id_mapping[cancer_type]
    cancer_specific_rna_df["cancer_id"] = cancer_specific_id
    return cancer_specific_rna_df

rna_blca_df = get_cancer_specific_rna_df(cancer_type="BLCA")
rna_lusc_df = get_cancer_specific_rna_df(cancer_type="LUSC")
rna_ov_df = get_cancer_specific_rna_df(cancer_type="OV")

rna_blca_genes_without_nans = set(column for column in rna_blca_df.dropna(axis=1).columns if column != "cancer_id")
rna_lusc_genes_without_nans = set(column for column in rna_lusc_df.dropna(axis=1).columns if column != "cancer_id")
rna_ov_genes_without_nans = set(column for column in rna_ov_df.dropna(axis=1).columns if column != "cancer_id")

selected_genes = rna_blca_genes_without_nans.intersection(rna_lusc_genes_without_nans)
selected_genes = list(selected_genes.intersection(rna_ov_genes_without_nans))

rna_blca_df = rna_blca_df[["cancer_id"] + selected_genes]
rna_lusc_df = rna_lusc_df[["cancer_id"] + selected_genes]
rna_ov_df = rna_ov_df[["cancer_id"] + selected_genes]


#     
#     cancer_specific
    
    

# blca_rna_df = get_cancer_specific_rna_df(cancer_type="BLCA")
    

# cna_blca_df = 
# cna_lusc_df = pd.read_csv(os.path.join(data_dir, raw_folder_name, cna_lusc_file_name), sep="\t")
# cna_ov_df = pd.read_csv(os.path.join(data_dir, raw_folder_name, cna_ov_file_name), sep="\t")


# blca_samples = 
# lusc_samples = [column for column in cna_lusc_df.columns if column.split("-")[-1] in tumor_sample_ids]
# ov_samples = [column for column in cna_ov_df.columns if column.split("-")[-1] in tumor_sample_ids]

# output_file_name = "rna.tsv"

# 

# cancer_symbol_id_map = {
#     "BLCA": 0,
#     "LUSC": 1,
#     "OV": 2
# }

# rna_blca_df["cancer_type"] = cancer_symbol_id_map["BLCA"]
# rna_lusc_df["cancer_type"] = cancer_symbol_id_map["LUSC"]
# rna_ov_df["cancer_type"] = cancer_symbol_id_map["OV"]


# # rna_lusc_df = rna_df[["gene_id"] + [column for column in rna_df.columns if column[:15] in lusc_samples]]
# # rna_lusc_df["cancer_type"] = cancer_symbol_id_map["LUSC"]

# # rna_ov_df = rna_df[["gene_id"] + [column for column in rna_df.columns if column[:15] in ov_samples]]
# # rna_ov_df["cancer_type"] = cancer_symbol_id_map["OV"]


# # # rna_blca_lusc_ov_df = rna_df[[column for column in rna_df.columns if column[:15] in blca_lusc_ov_samples]]

# # # We take only the tumor samples.
# # # If there are multiple samples which have the same project id, TSS id, participant id, and sample id,
# # # then we take the one with lexicographically first vial id. If there is also a tie in vial ids, then we
# # # take the one with (numerically, lexicographically) first (portion id, analyte id).

# # # column_dict = {}
# # # for column in rna_df.columns:
# # #     if column == "gene_id":
# # #         continue

# # #     if column.split("-")[3][:2] not in tumor_sample_ids:
# # #         continue

# # #     column_first_15 = column[:15]
# # #     if column_first_15 in column_dict.keys():
# # #         if column < column_dict[column_first_15]:
# # #             column_dict[column_first_15] = column
# # #         else:
# # #             continue
# # #     else:
# # #         column_dict[column_first_15] = column

# # # columns_before = rna_df.shape[0]
# # # rna_df = rna_df[["gene_id"] + list(column_dict.values())]
# # # columns_after = rna_df.shape[1]
# # # print(f"Number of samples dropped: {columns_before - columns_after}")

# # # rna_df.columns = rna_df.columns.map(lambda x: x[:15])

# # # # Drop the genes with nan values
# # # rows_before = rna_df.shape[0]
# # # rna_df = rna_df.dropna()
# # # rows_after = rna_df.shape[0]

# # # print(f"Number of genes dropped: {rows_before - rows_after}")

# # # 
# # # rna_df = rna_df.T
# # # rna_df.columns = rna_df.loc["gene_id", :].values
# # # rna_df = rna_df.drop("gene_id")

# # # rna_blca_df.to_csv(os.path.join(data_dir, processed_folder_name, "rna_blca.tsv"), sep="\t")
# # # rna_blca_lusc_ov_df.to_csv(os.path.join(data_dir, processed_folder_name, "rna_blca_lusc_ov.tsv"), sep="\t")

# %%
rna_blca_df = rna_blca_df[["cancer_id"] + selected_genes]
rna_lusc_df = rna_lusc_df[["cancer_id"] + selected_genes]
rna_ov_df = rna_ov_df[["cancer_id"] + selected_genes]

# %%
rna_blca_df
# Out:
#                  cancer_id    26220     6167     5792     1048    10809  \
# TCGA-2F-A9KO-01          0   4.0816  17261.8  9304.96  1388.34  557.434
# TCGA-2F-A9KP-01          0    2.913  18470.2  36166.9    2.913  862.672
# TCGA-2F-A9KQ-01          0  11.1266  12731.1  22019.5  554.937   2545.2
# TCGA-2F-A9KR-01          0  62.2071  15449.7  16615.5  2746.61  745.061
# TCGA-2F-A9KT-01          0   2256.6  32531.4  12169.0  704.353  2500.85
# ...                    ...      ...      ...      ...      ...      ...
# TCGA-ZF-AA56-01          0  10.1456  20182.2  13210.0  24877.4  1050.73
# TCGA-ZF-AA58-01          0  76.7285  17615.5  10836.0   1.6863  639.966
# TCGA-ZF-AA5H-01          0    24.91  19008.9  12204.6   0.3235  1685.79
# TCGA-ZF-AA5N-01          0  53.9877  24116.6  9538.65  69.9387  3440.49
# TCGA-ZF-AA5P-01          0      0.0  16426.3  3163.98  72.2624   688.16
#
#                    23635   151393   724102    93556  ...    51096     9420  \
# TCGA-2F-A9KO-01  199.417  89.7959  12.1399      0.0  ...  906.122  47.8134
# TCGA-2F-A9KP-01  59.0928  61.5897  46.6875   3.7453  ...  908.448   5.8261
# TCGA-2F-A9KQ-01  200.278  37.5522  14.6685  11.5902  ...  884.562  50.0695
# TCGA-2F-A9KR-01  216.063  74.5536  30.4388      0.0  ...  1047.07  107.319
# TCGA-2F-A9KT-01  34.4828  23.7422  11.5885      0.0  ...  584.511   9.0447
# ...                  ...      ...      ...      ...  ...      ...      ...
# TCGA-ZF-AA56-01  199.824  91.7512   8.3194   0.4411  ...  910.013   67.049
# TCGA-ZF-AA58-01  45.5312  56.0708   3.9713      0.0  ...  992.833   29.511
# TCGA-ZF-AA5H-01  179.546  19.0869   2.3713   1.6175  ...   1241.3  21.3514
# TCGA-ZF-AA5N-01  203.681  35.5828    8.589    9.816  ...  709.202    2.454
# TCGA-ZF-AA5P-01   385.77  65.0361   6.3646      0.0  ...  769.316  46.1367
#
#                    55869  285555   203245    64897     5689    84515   346007  \
# TCGA-2F-A9KO-01  401.166  1.7493  274.636  254.227  2155.69  494.461   8.1633
# TCGA-2F-A9KP-01  387.849  0.4161  284.644  230.129  3184.77   362.88   4.9938
# TCGA-2F-A9KQ-01   350.95  1.3908  180.807  454.798  3751.04  247.566  11.5902
# TCGA-2F-A9KR-01  419.305  0.9497  246.929  134.861  1684.34  210.365   4.7486
# TCGA-2F-A9KT-01  325.608  0.5653  283.776  196.156  3058.79  279.254   6.2182
# ...                  ...     ...      ...      ...      ...      ...      ...
# TCGA-ZF-AA56-01  261.579     0.0  302.603   218.35   5419.5  273.048   1.3233
#
#        gender vital_status days_to_birth     days_to_death  \
# 0        MALE         Dead        -21496            1355.0
# 1      FEMALE         Dead        -16090              1677
# 2      FEMALE        Alive         -8624  [Not Applicable]
# 3      FEMALE         Dead         -8451               423
# 4        MALE         Dead        -11171               365
# ...       ...          ...           ...               ...
# 10951    MALE        Alive        -27716  [Not Applicable]
# 10952  FEMALE        Alive        -28938  [Not Applicable]
# 10953  FEMALE        Alive        -18769  [Not Applicable]
# 10954  FEMALE         Dead        -18342            1396.0
# 10955  FEMALE        Alive        -15164  [Not Applicable]
#
#       days_to_last_followup days_to_initial_pathologic_diagnosis  \
# 0           [Not Available]                                    0
# 1           [Not Available]                                    0
# 2                    2091.0                                    0
# 3           [Not Available]                                    0
# 4           [Not Available]                                    0
# ...                     ...                                  ...
# 10951                1601.0                                    0
# 10952                 495.0                                    0
# 10953                 547.0                                    0
# 10954                1280.0                                    0
# 10955                 974.0                                    0
#
#       age_at_initial_pathologic_diagnosis  ... total_bilirubin_upper_limit  \
# 0                                      58  ...                         NaN
# 1                                      44  ...                         NaN
# 2                                      23  ...                         NaN
# 3                                      23  ...                         NaN
# 4                                      30  ...                         NaN
# ...                                   ...  ...                         ...
# 10951                                  75  ...                         NaN
# 10952                                  79  ...                         NaN
# 10953                                  51  ...                         NaN
# 10954                                  50  ...                         NaN
# 10955                                  41  ...                         NaN
#
#       platelet_result_count fibrosis_ishak_score fetoprotein_outcome_value  \
# 0                       NaN                  NaN                       NaN
# 1                       NaN                  NaN                       NaN
# 2                       NaN                  NaN                       NaN
# 3                       NaN                  NaN                       NaN
# 4                       NaN                  NaN                       NaN
# ...                     ...                  ...                       ...
# 10951                   NaN                  NaN                       NaN
# 10952                   NaN                  NaN                       NaN
# 10953                   NaN                  NaN                       NaN
# 10954                   NaN                  NaN                       NaN
# 10955                   NaN                  NaN                       NaN
#
#       fetoprotein_outcome_upper_limit fetoprotein_outcome_lower_limit  \
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
# ...                               ...                             ...
# 10951                             NaN                             NaN
# 10952                             NaN                             NaN
# 10953                             NaN                             NaN
# 10954                             NaN                             NaN
# 10955                             NaN                             NaN
#
#       inter_norm_ratio_lower_limit family_cancer_type_txt  \
# 0                              NaN                    NaN
# 1                              NaN                    NaN
# 2                              NaN                    NaN
# 3                              NaN                    NaN
# 4                              NaN                    NaN
# ...                            ...                    ...
# 10951                          NaN                    NaN
# 10952                          NaN                    NaN
# 10953                          NaN                    NaN
# 10954                          NaN                    NaN
# 10955                          NaN                    NaN
#
#       bilirubin_upper_limit days_to_last_known_alive
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                       NaN                      NaN
# ...                     ...                      ...
# 10951                   NaN                      NaN
# 10952                   NaN                      NaN
# 10953                   NaN                      NaN
# 10954                   NaN                      NaN
# 10955                   NaN                      NaN
#
# [10956 rows x 746 columns]
